# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def load_datasets(filename, data_columns, target_column):
    df = pd.read_csv(filename)
    X, y = df[data_columns], df[target_column]
    return X, y

# %%
def plot_data(A, b, test = False):
    positive_indices = np.where(b == 1)[0]
    negative_indices = np.where(b == 0)[0]
    
    plt.scatter(A.iloc[positive_indices, 0], A.iloc[positive_indices, 1], marker='x', c= 'yellow' if test else 'green')
    plt.scatter(A.iloc[negative_indices, 0], A.iloc[negative_indices, 1], marker='+', c= 'blue' if test else 'red')
    
   # plt.show()

# %%
def decision_boundary(X, y, mean, std, theta):
    X =(X-mean)/std;
    positive_indices = np.where(y == 1)[0]
    negative_indices = np.where(y == 0)[0]
    
    plt.scatter(X.iloc[positive_indices, 0], X.iloc[positive_indices, 1], marker='*', c= 'violet')
    plt.scatter(X.iloc[negative_indices, 0], X.iloc[negative_indices, 1], marker='+', c= 'orange')

# %%
def normalize(X):
    mean = np.mean(X,axis=0);
    std = np.std(X,axis=0);
    X_new = (X-mean)/std;
    
return X_new, mean, std
# Out:
#   File "<ipython-input-35-1b272a53ce7a>", line 6
#     return X_new, mean, std
#                            ^
# SyntaxError: 'return' outside function

# %%
def prepare_X(X):
    m = X.shape[0]
    ones = np.ones((m, 1))
    X_new = np.column_stack((ones, X))
return X_new
# Out:
#   File "<ipython-input-36-751bc3cf94ce>", line 5
#     return X_new
#                 ^
# SyntaxError: 'return' outside function

# %%
def sigmoid(z):
    g = 1/(1+np.exp(z*-1));
return g
# Out:
#   File "<ipython-input-37-414bd68c6189>", line 3
#     return g
#             ^
# SyntaxError: 'return' outside function

# %%
def h(X, theta):
    z = X.dot(theta)
return sigmoid(z)
# Out:
#   File "<ipython-input-38-c638d11c2343>", line 3
#     return sigmoid(z)
#                      ^
# SyntaxError: 'return' outside function

# %%
def cost_function(X, y, theta):
    m = X.shape[0]
    
    if m ==0:
        return None
    temp =h(X,theta);
    J = sum( (1-y)*np.log(1-temp)+(-1)*y*np.log(temp))/m;
return J
# Out:
#   File "<ipython-input-39-4a3e2477c59e>", line 8
#     return J
#             ^
# SyntaxError: 'return' outside function

# %%
def derivative_theta(X, y, theta):
    m = X.shape[0]
    
    if m == 0:
        return None
    d_theta = X_new.T.dot(h(X_new,theta) - y_new)/m;
    
return d_theta
# Out:
#   File "<ipython-input-40-32ed720bc527>", line 8
#     return d_theta
#                   ^
# SyntaxError: 'return' outside function

# %%
def gradient_descent(X, y, theta, alpha, epsilon, num_iters, print_J = True):
    m = X.shape[0]
    J_history = []
    
    J = cost_function(X,y,theta);
    
    if print_J == True:
    print(J)
    J_history.append(J)
    
    for i in range(num_iters):
        
        theta = theta - alpha* derivative_theta(X,y,theta);
        
        J = cost_function(X,y,theta);
        
        J_history.append(J)
        
        if i % 1000 == 0 and print_J == True:
            print(J)
        
        if abs(J-J_history[-2]) < epsilon:
            break
            
return theta, J_history
# Out:
#   File "<ipython-input-41-e62041899b5c>", line 8
#     print(J)
#         ^
# IndentationError: expected an indented block

# %%
def predict(X, mean, std, theta):
    predictions = h(prepare_X((X-mean.values)/std.values),theta)
return predictions
# Out:
#   File "<ipython-input-42-736f37e1f786>", line 3
#     return predictions
#                       ^
# SyntaxError: 'return' outside function

# %%
data_columns = ["exam1", "exam2"]
target_column = "submitted"
X, y = load_datasets('sats.csv', data_columns, target_column)
print('Training set: X={}, y={}'.format(X.shape, y.shape))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-bad9e2d379e5> in <module>
#       1 data_columns = ["exam1", "exam2"]
#       2 target_column = "submitted"
# ----> 3 X, y = load_datasets('sats.csv', data_columns, target_column)
#       4 print('Training set: X={}, y={}'.format(X.shape, y.shape))
#
# <ipython-input-31-8625b30c8d1b> in load_datasets(filename, data_columns, target_column)
#       1 def load_datasets(filename, data_columns, target_column):
# ----> 2     df = pd.read_csv(filename)
#       3     X, y = df[data_columns], df[target_column]
#       4     return X, y
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1366             compression=kwds.get("compression", None),
#    1367             memory_map=kwds.get("memory_map", False),
# -> 1368             storage_options=kwds.get("storage_options", None),
#    1369         )
#    1370
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     645                 encoding=ioargs.encoding,
#     646                 errors=errors,
# --> 647                 newline="",
#     648             )
#     649         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sats.csv'

# %%
data_columns = ["test1", "test2"]
target_column = "passed"
X, y = load_datasets('tests.csv', data_columns, target_column)
print('Training set: X={}, y={}'.format(X.shape, y.shape))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-44-9eb9e37e3761> in <module>
#       1 data_columns = ["test1", "test2"]
#       2 target_column = "passed"
# ----> 3 X, y = load_datasets('tests.csv', data_columns, target_column)
#       4 print('Training set: X={}, y={}'.format(X.shape, y.shape))
#
# <ipython-input-31-8625b30c8d1b> in load_datasets(filename, data_columns, target_column)
#       1 def load_datasets(filename, data_columns, target_column):
# ----> 2     df = pd.read_csv(filename)
#       3     X, y = df[data_columns], df[target_column]
#       4     return X, y
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1366             compression=kwds.get("compression", None),
#    1367             memory_map=kwds.get("memory_map", False),
# -> 1368             storage_options=kwds.get("storage_options", None),
#    1369         )
#    1370
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     645                 encoding=ioargs.encoding,
#     646                 errors=errors,
# --> 647                 newline="",
#     648             )
#     649         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tests.csv'

# %%
plot_data(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-a8d97920f158> in <module>
# ----> 1 plot_data(X, y)
#
# NameError: name 'X' is not defined

# %%
X_new, mean, std = normalize(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-4e2fc5c65fc6> in <module>
# ----> 1 X_new, mean, std = normalize(X)
#
# NameError: name 'X' is not defined

# %%
X_new = prepare_X(X_new)
y=y.to_numpy();
y_new = y.reshape((X.shape[0], 1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-ce3174ccdf8a> in <module>
# ----> 1 X_new = prepare_X(X_new)
#       2 y=y.to_numpy();
#       3 y_new = y.reshape((X.shape[0], 1))
#
# NameError: name 'X_new' is not defined

# %%
theta = np.zeros((X_new.shape[1], 1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-549ef7156875> in <module>
# ----> 1 theta = np.zeros((X_new.shape[1], 1))
#
# NameError: name 'X_new' is not defined

# %%
cost_function(X_new, y_new, theta)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-9deea7b3ac78> in <module>
# ----> 1 cost_function(X_new, y_new, theta)
#
# NameError: name 'X_new' is not defined

# %%
new_theta, Js = gradient_descent(X_new, y_new, theta, 0.01, 1e-7, 1000000, False)
print(new_theta, len(Js))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-13011475304f> in <module>
# ----> 1 new_theta, Js = gradient_descent(X_new, y_new, theta, 0.01, 1e-7, 1000000, False)
#       2 print(new_theta, len(Js))
#
# NameError: name 'gradient_descent' is not defined

# %%
cost_function(X_new, y_new, new_theta)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-d92eccbb9f34> in <module>
# ----> 1 cost_function(X_new, y_new, new_theta)
#
# NameError: name 'X_new' is not defined

# %%
decision_boundary(X, y, mean, std, new_theta)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-bb73abf047d0> in <module>
# ----> 1 decision_boundary(X, y, mean, std, new_theta)
#
# NameError: name 'X' is not defined

# %%
T = np.array([[40, 40], [60, 65]])
print(predict(T, mean, std, new_theta))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-f627489bde48> in <module>
#       1 T = np.array([[40, 40], [60, 65]])
# ----> 2 print(predict(T, mean, std, new_theta))
#
# NameError: name 'mean' is not defined
