# %%
import numpy as np
import random as rand
import time

# %%
def mnoj (A, B):
    C = [[0 for row in range(len(A))] for col in range(len(B[0]))]
    for i in range(len(A)):
        for j in range(len(B[0])):
            for k in range(len(B)):
                C[i][j] += A[i][k]*B[k][j]
    return C

# %%
n = 100
A1 = np.random.randint(n, size=(n, n))
B2 = np.random.randint(n, size=(n, n))
start_time = time.time()
C3 = np.dot(A1,B2)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.0013263225555419922 seconds ---

# %%
n = 100;
A = [[rand.random() for i in range(n)] for j in range(n)]
B = [[rand.random() for i in range(n)] for j in range(n)]
start_time = time.time()
mnoj(A,B)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.1736767292022705 seconds ---
